# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from astropy.io import fits 
from astropy.table import Table 
from matplotlib.colors import LogNorm

# %%
event_PMAT= '/Users/kate/Desktop/Summer work/kepler data and notebooks/kplr_anc-eng_TH2PMAT.fits'
hdul=fits.open(event_PMAT, mmemmap=True)

# %%
table_hdu=hdul[1]
df=pd.DataFrame(table_hdu.data)
print(df.head())
# Out:
#             MJD                      UTC     LC   SC    TH2PMAT
# 0  54949.283051  2009-04-28T06:47:35.600  384.0  1.0 -28.640933
# 1  54949.283120  2009-04-28T06:47:41.600  384.0  1.0 -28.640933
# 2  54949.283722  2009-04-28T06:48:33.600  384.0  2.0 -28.640933
# 3  54949.284394  2009-04-28T06:49:31.600  384.0  3.0 -27.146481
# 4  54949.284486  2009-04-28T06:49:39.600  384.0  3.0 -28.640933

# %%
evt_data=Table(hdul[1].data)
evt_data
# Out:
# <Table length=2432989>
#        MJD                   UTC              LC       SC          TH2PMAT
#      float64                str23          float64  float64        float64
# ------------------ ----------------------- ------- --------- -------------------
# 54949.283050925995 2009-04-28T06:47:35.600   384.0       1.0 -28.640933489281448
#     54949.28312037 2009-04-28T06:47:41.600   384.0       1.0 -28.640933489281448
# 54949.283722222004 2009-04-28T06:48:33.600   384.0       2.0 -28.640933489281448
#    54949.284393519 2009-04-28T06:49:31.600   384.0       3.0  -27.14648065099027
#    54949.284486111 2009-04-28T06:49:39.600   384.0       3.0 -28.640933489281448
# 54949.285064722004 2009-04-28T06:50:29.592   384.0       4.0 -28.640933489281448
#  54949.28573611099 2009-04-28T06:51:27.600   384.0       5.0  -27.14648065099027
#    54949.285851852 2009-04-28T06:51:37.600   384.0       6.0  -27.14648065099027
# ...

# %%
from astropy.timeseries import LombScargle
import datetime
from datetime import datetime

# %%
df['UTC']=pd.to_datetime(df['UTC'])

# %%
print(df)
# Out:
#                   MJD                     UTC       LC         SC    TH2PMAT
# 0        54949.283051 2009-04-28 06:47:35.600    384.0        1.0 -28.640933
# 1        54949.283120 2009-04-28 06:47:41.600    384.0        1.0 -28.640933
# 2        54949.283722 2009-04-28 06:48:33.600    384.0        2.0 -28.640933
# 3        54949.284394 2009-04-28 06:49:31.600    384.0        3.0 -27.146481
# 4        54949.284486 2009-04-28 06:49:39.600    384.0        3.0 -28.640933
# ...               ...                     ...      ...        ...        ...
# 2432984  56728.010050 2014-03-12 00:14:28.349  87433.0  2611475.0 -24.154945
# 2432985  56728.010722 2014-03-12 00:15:26.349  87433.0  2611476.0 -24.154945
# 2432986  56728.011393 2014-03-12 00:16:24.340  87433.0  2611477.0 -24.154945
# 2432987  56728.012064 2014-03-12 00:17:22.340  87433.0  2611478.0 -24.154945
# 2432988  56728.012735 2014-03-12 00:18:20.340  87433.0  2611479.0 -24.154945
#
# [2432989 rows x 5 columns]

# %%
full_2010 = df[df['UTC'].dt.year == 2010]
print(full_2010)
# Out:
#                  MJD                     UTC       LC        SC    TH2PMAT
# 403643  55197.000229 2010-01-01 00:00:19.812  12507.0  363692.0 -27.146481
# 403644  55197.000901 2010-01-01 00:01:17.812  12507.0  363693.0 -27.146481
# 403645  55197.001572 2010-01-01 00:02:15.812  12507.0  363694.0 -27.146481
# 403646  55197.002243 2010-01-01 00:03:13.812  12507.0  363695.0 -27.146481
# 403647  55197.002914 2010-01-01 00:04:11.812  12507.0  363696.0 -27.146481
# ...              ...                     ...      ...       ...        ...
# 963341  55561.996869 2010-12-31 23:55:29.518  30370.0  899570.0 -25.651151
# 963342  55561.997541 2010-12-31 23:56:27.518  30370.0  899571.0 -25.651151
# 963343  55561.998212 2010-12-31 23:57:25.518  30370.0  899572.0 -25.651151
# 963344  55561.998883 2010-12-31 23:58:23.518  30370.0  899573.0 -25.651151
# 963345  55561.999555 2010-12-31 23:59:21.518  30370.0  899574.0 -25.651151
#
# [559703 rows x 5 columns]

# %%
time = full_2010['MJD']*86400
y = full_2010['TH2PMAT']

# %%
frequency, power = LombScargle(time, y).autopower()

# %%
plt.plot(frequency, power)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power')
plt.title('TH2PMAT All 2010 Lomb-Scargle Periodogram')
plt.show()
