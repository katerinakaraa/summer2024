# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from astropy.io import fits 
from astropy.table import Table 
from matplotlib.colors import LogNorm 
from astropy.utils.data import download_file

# %%
event_optics_temp2= '/Users/kate/Desktop/Summer work/kepler data and notebooks/kplr_anc-eng_OpticsTemperatures1of2.fits'
hdul=fits.open(event_optics_temp2, mmemmap=True)

# %%
table_hdu=hdul[1]
df=pd.DataFrame(table_hdu.data)
print(df.head())
# Out:
#             MJD                      UTC     LC      SC   PEDCRRT1   PEDCRRT2  \
# 0  54952.905681  2009-05-01T21:44:10.810  562.0  5320.0 -66.514564 -65.140955
# 1  54952.906372  2009-05-01T21:45:10.547  562.0  5321.0 -66.514564 -65.140955
# 2  54952.907064  2009-05-01T21:46:10.290  562.0  5322.0 -66.514564 -65.140955
# 3  54952.907755  2009-05-01T21:47:10.060  562.0  5323.0 -66.514564 -65.140955
# 4  54952.908447  2009-05-01T21:48:09.810  562.0  5324.0 -66.514564 -65.140955
#
#     PEDCRRT3   PEDPMAT1   PEDPMAT2   PEDPMAT3   PEDPMAT4
# 0 -57.054846 -27.349498 -27.814515 -26.942541 -26.709965
# 1 -57.054846 -27.349498 -27.814515 -26.942541 -26.709965
# 2 -57.054846 -27.349498 -27.814515 -26.942541 -26.709965
# 3 -57.054846 -27.349498 -27.814515 -26.942541 -26.709965
# 4 -57.054846 -27.349498 -27.814515 -26.942541 -26.709965

# %%
evt_data=Table(hdul[1].data)
evt_data
# Out:
# <Table length=3360811>
#        MJD                   UTC           ...       PEDPMAT4
#      float64                str23          ...       float64
# ------------------ ----------------------- ... -------------------
#    54952.905680671 2009-05-01T21:44:10.810 ... -26.709965371627003
#    54952.906372068 2009-05-01T21:45:10.547 ... -26.709965371627003
#    54952.907063542 2009-05-01T21:46:10.290 ... -26.709965371627003
# 54952.907755324006 2009-05-01T21:47:10.060 ... -26.709965371627003
#    54952.908446875 2009-05-01T21:48:09.810 ... -26.709965371627003
#    54952.909138272 2009-05-01T21:49:09.547 ... -26.709965371627003
#  54952.90982974599 2009-05-01T21:50:09.290 ... -26.709965371627003
#    54952.910521142 2009-05-01T21:51:09.027 ... -26.709965371627003
#    54952.911213079 2009-05-01T21:52:08.810 ... -26.709965371627003
#                ...                     ... ...                 ...
#  56424.20098271599 2013-05-12T04:49:24.907 ... -25.895788951704002
# ...

# %%
hdul.close()
