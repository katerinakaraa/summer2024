# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from astropy.io import fits 
from astropy.table import Table 
from matplotlib.colors import LogNorm

# %%
event_telescope_temp1= '/Users/kate/Desktop/Summer_work/kepler_data_and_notebooks/kplr_anc-eng_TelescopeTemperatures1of2.fits'
hdul=fits.open(event_telescope_temp1, mmemmap=True)

# %%
table_hdu=hdul[1]
df=pd.DataFrame(table_hdu.data)
print(df.head())
# Out:
#             MJD                      UTC     LC      SC  TH1SCMNTT  TH2SCMNTT
# 0  54952.905437  2009-05-01T21:43:49.777  562.0  5320.0 -11.378122 -15.236631
# 1  54952.906108  2009-05-01T21:44:47.770  562.0  5321.0 -11.378122 -15.236631
# 2  54952.906271  2009-05-01T21:45:01.777  562.0  5321.0 -11.378122 -15.236631
# 3  54952.906780  2009-05-01T21:45:45.777  562.0  5322.0 -11.378122 -15.236631
# 4  54952.907451  2009-05-01T21:46:43.777  562.0  5323.0 -11.378122 -15.236631

# %%
evt_data=Table(hdul[1].data)
evt_data
# Out:
# <Table length=2080771>
#        MJD                   UTC           ...    TH1SCMNTT        TH2SCMNTT
#      float64                str23          ...     float64          float64
# ------------------ ----------------------- ... ---------------- ----------------
#     54952.90543723 2009-05-01T21:43:49.777 ... -11.378122428648 -15.236630675818
#    54952.906108449 2009-05-01T21:44:47.770 ... -11.378122428648 -15.236630675818
#    54952.906270563 2009-05-01T21:45:01.777 ... -11.378122428648 -15.236630675818
#    54952.906779822 2009-05-01T21:45:45.777 ... -11.378122428648 -15.236630675818
# 54952.907451119005 2009-05-01T21:46:43.777 ... -11.378122428648 -15.236630675818
#    54952.907636304 2009-05-01T21:46:59.777 ... -11.378122428648 -15.236630675818
#    54952.908122415 2009-05-01T21:47:41.777 ... -11.378122428648 -15.236630675818
#    54952.908793712 2009-05-01T21:48:39.777 ... -11.378122428648 -15.236630675818
# ...

# %%
from astropy.timeseries import LombScargle
import datetime
from datetime import datetime

# %%
df['UTC']=pd.to_datetime(df['UTC'])
print(df)
# Out:
#                   MJD                     UTC       LC         SC  TH1SCMNTT  \
# 0        54952.905437 2009-05-01 21:43:49.777    562.0     5320.0 -11.378122
# 1        54952.906108 2009-05-01 21:44:47.770    562.0     5321.0 -11.378122
# 2        54952.906271 2009-05-01 21:45:01.777    562.0     5321.0 -11.378122
# 3        54952.906780 2009-05-01 21:45:45.777    562.0     5322.0 -11.378122
# 4        54952.907451 2009-05-01 21:46:43.777    562.0     5323.0 -11.378122
# ...               ...                     ...      ...        ...        ...
# 2080766  56424.202872 2013-05-12 04:52:08.127  72565.0  2165435.0 -12.315181
# 2080767  56424.203543 2013-05-12 04:53:06.127  72565.0  2165436.0 -12.001465
# 2080768  56424.204214 2013-05-12 04:54:04.127  72565.0  2165437.0 -12.001465
# 2080769  56424.204886 2013-05-12 04:55:02.127  72565.0  2165438.0 -12.315181
# 2080770  56424.205557 2013-05-12 04:56:00.127  72565.0  2165439.0 -12.001465
#
#          TH2SCMNTT
# 0       -15.236631
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2080771 entries, 0 to 2080770
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   MJD        float64
#  1   UTC        datetime64[ns]
#  2   LC         float64
#  3   SC         float64
#  4   TH1SCMNTT  float64
#  5   TH2SCMNTT  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 95.3 MB

# %%
full_2010 = df[df['UTC'].dt.year == 2010]
print(full_2010)
# Out:
#                  MJD                     UTC       LC        SC  TH1SCMNTT  \
# 367061  55197.000231 2010-01-01 00:00:19.993  12507.0  363692.0 -16.620501
# 367062  55197.000903 2010-01-01 00:01:17.993  12507.0  363693.0 -16.268005
# 367063  55197.001574 2010-01-01 00:02:15.993  12507.0  363694.0 -16.268005
# 367064  55197.002245 2010-01-01 00:03:13.993  12507.0  363695.0 -16.268005
# 367065  55197.002917 2010-01-01 00:04:11.993  12507.0  363696.0 -16.268005
# ...              ...                     ...      ...       ...        ...
# 899908  55552.178956 2010-12-22 04:17:41.810  29889.0  885155.0 -13.912025
# 899909  55552.179627 2010-12-22 04:18:39.810  29889.0  885156.0 -13.912025
# 899910  55552.180299 2010-12-22 04:19:37.810  29889.0  885157.0 -13.912025
# 899911  55552.180970 2010-12-22 04:20:35.810  29889.0  885158.0 -13.912025
# 899912  55552.181641 2010-12-22 04:21:33.810  29889.0  885159.0 -13.912025
#
#         TH2SCMNTT
# 367061 -18.462139
# 367062 -18.462139
# ...

# %%
time = full_2010['MJD']*86400
y1 = full_2010['TH1SCMNTT']

# %%
frequency, power = LombScargle(time, y1).autopower()

# %%
plt.plot(frequency, power)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power')
plt.title('Telecsope Temperatures 1 All 2010 Lomb-Scargle Periodogram')
plt.show()

# %%
y2 = full_2010['TH2SCMNTT']
frequency, power = LombScargle(time, y1).autopower()

# %%
plt.plot(frequency, power)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power')
plt.title('Telecsope Temperatures 2 All 2010 Lomb-Scargle Periodogram')
plt.show()
