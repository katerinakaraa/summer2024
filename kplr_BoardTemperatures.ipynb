# %%
event_board_temperature = '/Users/kate/Desktop/Summer work/kepler data and notebooks/kplr_anc-eng_BoardTemperatures.fits'

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from astropy.io import fits 
from astropy.table import Table 
from matplotlib.colors import LogNorm 
from astropy.utils.data import download_file

# %%
hdul=fits.open(event_board_temperature, mmemmap=True)

# %%
hdul.info()
# Out:
# Filename: /Users/kate/Desktop/Summer work/kepler data and notebooks/kplr_anc-eng_BoardTemperatures.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      11   ()
#   1                1 BinTableHDU     38   1989143R x 14C   [D, 23A, D, D, D, D, D, D, D, D, D, D, D, D]

# %%
table_hdu = hdul[1]
df = pd.DataFrame(table_hdu.data)
print(df.head())
# Out:
#             MJD                      UTC     LC      SC   PEDDRV1T   PEDACQ1T  \
# 0  54952.905681  2009-05-01T21:44:10.810  562.0  5320.0  27.744580  30.716671
# 1  54952.906372  2009-05-01T21:45:10.547  562.0  5321.0  27.767699  30.751381
# 2  54952.907064  2009-05-01T21:46:10.290  562.0  5322.0  27.756139  30.739811
# 3  54952.907755  2009-05-01T21:47:10.060  562.0  5323.0  27.744580  30.705101
# 4  54952.908447  2009-05-01T21:48:09.810  562.0  5324.0  27.744580  30.728241
#
#     PEDDRV2T   PEDACQ2T   PEDDRV3T   PEDACQ3T   PEDDRV4T   PEDACQ4T  \
# 0  29.802780  32.707303  30.427437  33.031476  28.993219  32.093780
# 1  29.849046  32.707303  30.450575  32.996742  29.004782  32.070631
# 2  29.849046  32.684150  30.439006  33.031476  29.027910  32.070631
# 3  29.802780  32.672573  30.462144  33.043054  28.993219  32.070631
# 4  29.872180  32.695726  30.450575  32.985164  28.993219  32.047481
#
#     PEDDRV5T   PEDACQ5T
# 0  29.201372  32.209530
# 1  29.189808  32.209530
# ...

# %%
evt_data = Table(hdul[1].data)
evt_data
# Out:
# <Table length=1989143>
#        MJD                   UTC           ...     PEDACQ5T
#      float64                str23          ...     float64
# ------------------ ----------------------- ... ---------------
#    54952.905680671 2009-05-01T21:44:10.810 ... 32.209530413084
#    54952.906372068 2009-05-01T21:45:10.547 ... 32.209530413084
#    54952.907063542 2009-05-01T21:46:10.290 ... 32.232680948468
# 54952.907755324006 2009-05-01T21:47:10.060 ... 32.174804920793
#    54952.908446875 2009-05-01T21:48:09.810 ... 32.209530413084
#    54952.909138272 2009-05-01T21:49:09.547 ... 32.221105660057
#  54952.90982974599 2009-05-01T21:50:09.290 ... 32.221105660057
#    54952.910521142 2009-05-01T21:51:09.027 ... 32.209530413084
#    54952.911213079 2009-05-01T21:52:08.810 ... 32.197955207549
#                ...                     ... ...             ...
#    56424.200985378 2013-05-12T04:49:25.137 ... 32.070630681572
#    56424.201677161 2013-05-12T04:50:24.907 ... 32.059055973293
# ...

# %%
hdul.close()
